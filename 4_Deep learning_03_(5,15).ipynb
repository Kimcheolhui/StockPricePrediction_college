# %% [markdown]
# <span style='font-size:150%'>딥러닝 수행 (10점) - TensorFlow, Keras를 활용하여 딥러닝 수행</span>
#
# 다양한 방식으로 딥러닝을 수행한 코딩을 모두 제출할 것
#
# 파일명 : 4_Deep learning_1.ipynb
#
# (여러개의 파일을 사용한 경우 Deep learning_2.ipynb, Deep learning_3.ipynb...)

# %%
import numpy as np
import pandas as pd

import os
import matplotlib.pyplot as plt
import matplotlib.font_manager

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

seed=0
np.random.seed(3)
tf.random.set_seed(3)

# %%
import os
os.getcwd()
# Out:
# 'D:\\ai\\Final'

# %% [markdown]
# # 데이터
# Data_set_1 : 종가,시가, 고가, 저가, 거래량, 변동 데이터가 담김. 아직 클래스 데이터 문자 형태
# Data_set_2 : 기존 속성 데이터들을 속성들 간의 차로 변경. 스케일링됨. 클래스 데이터 숫자 형태

# %%
# 데이터 불러오기

# 일반 데이터
data_set=pd.read_csv("D:/ai/Final/Data set_2.csv")

# %%
data_set
# Out:
#      close-start  high-low  high-close  high-start  close-low  start-low  \
# 0       0.541985  0.033708    0.067568    0.084337   0.051282   0.024390
# 1       0.465649  0.168539    0.121622    0.012048   0.153846   0.243902
# 2       0.465649  0.112360    0.202703    0.084337   0.012821   0.109756
# 3       0.633588  0.101124    0.000000    0.168675   0.192308   0.012195
# 4       0.412214  0.112360    0.202703    0.000000   0.012821   0.195122
# ..           ...       ...         ...         ...        ...        ...
# 594     0.603053  0.292135    0.162162    0.265060   0.256410   0.121951
# 595     0.450382  0.224719    0.324324    0.168675   0.025641   0.146341
# 596     0.801527  0.359551    0.000000    0.433735   0.487179   0.024390
# 597     0.557252  0.224719    0.243243    0.265060   0.102564   0.048780
# 598     0.511450  0.089888    0.108108    0.072289   0.076923   0.097561
#
#        volume  Diff
# 0    0.111197     0
# 1    0.123828     1
# 2    0.134799     1
# 3    0.129628     0
# 4    0.059433     1
# ..        ...   ...
# 594  0.437442     0
# 595  0.374049     1
# 596  0.357297     0
# 597  0.644365     1
# 598  0.254465     0
#
# [599 rows x 8 columns]

# %% [markdown]
# # 데이터셋 설정

# %% [markdown]
# 주가를 예측하는 것은 시계열 데이터를 필요로 하기 때문에 기존 데이터를 시계열 데이터에 맞게 변형을 해줘야 한다.
# 며칠 동안의 데이터를 가지고 예측을 할지를 window_size에 입력받고, 해당 숫자를 기반으로 시계열 데이터를 생성할 것이다.
# window_size에 따라 딥러닝 결과가 달라질 수 있기 때문에 시계열 데이터를 '2_...'나 '3_...'에서 만들지 않고 '4_...'에서 바로바로 만들어서 사용했다.

# %% [markdown]
# 또한 여러번 실행을 해보기 위해 함수를 사용했다.

# %%
# window의 사이즈와 train dataset의 사이즈 입력받는 함수

def set_window_train_size(data):
    
    # 학습 데이터셋 70% 테스트 데이터셋 30%로 나눈다. (고정)
    train_size=int(len(data)*0.7) 
    
    # 시계열 데이터셋을 만들 때, 몇 개의 데이터를 가지고 만들지 설정한다.
    # 예 : window_size=30 => 30일간의 데이터를 가진 시계열 데이터셋
    window_size=int(input("window size : "))

    return window_size, train_size

# %%
# feature 데이터와 class 데이터를 구분

def split_feature_class(data):
    
    #feature_cols = ['close-start', 'high-low', 'high-close', 'high-start','close-low','start-low','volume']
    #close_cols = ['close']
    
    feature_cols = ['close-start', 'high-low', 'high-close', 'high-start','close-low','start-low','volume']
    close_cols = ['Diff']
    
    data_feature = data[feature_cols]
    data_close = data[close_cols]
    
    return data_feature, data_close

# %%
# window_size에 따라 데이터를 묶어주고 새로운 데이터셋 리턴
def make_window_data(feature_data, class_data, window_size):
    
    feature_list=[]
    class_list=[]
    
    for i in range(len(feature_data)-window_size):
        feature_list.append(np.array(feature_data.iloc[i:i+window_size]))
        class_list.append(np.array(class_data.iloc[i+window_size]))
    
    return np.array(feature_list), np.array(class_list)

# %%
def make_dataset(data):
    
    # 시계열 데이터 크기(window_size)와 학습 데이터(train_size)의 크기
    window_size, train_size=set_window_train_size(data)
    
    # 학습 데이터셋과 테스트 데이터셋 분리
    train = data[:train_size] 
    test = data[train_size:] 
    
    train_feature, train_class = split_feature_class(train)
    test_feature, test_class = split_feature_class(test)
    
    train_feature, train_class = make_window_data(train_feature, train_class, window_size)
    test_feature, test_class = make_window_data(test_feature, test_class, window_size)
    
    return train_feature, train_class, test_feature, test_class, window_size

# %%
# 학습 데이터셋을 train과 valid로 분리

def train_valid(train_feature,train_class):
    split_size= float(input("학습 데이터 중 test size(validation data의 size)의 비율 (예 : 0.2) : "))
    X_train, X_valid, Y_train, Y_valid = train_test_split(train_feature, train_class, test_size = split_size, random_state=seed)
    return X_train, X_valid, Y_train, Y_valid

# %% [markdown]
# # 기본 데이터에 대한 딥러닝

# %%
train_feature, train_class, test_feature, test_class, window_size = make_dataset(data_set)

X_train, X_valid, Y_train, Y_valid = train_valid(train_feature, train_class)
# Out:
# window size : 5
# 학습 데이터 중 test size(validation data의 size)의 비율 (예 : 0.2) : 0.2

# %% [markdown]
# <span style='font-size:150%'>[LSTM]</span>
#
# 시계열 데이터이기 때문에 LSTM을 사용했다.
# 2진 class이기 때문에  활성화 함수로 'sigmoid'를, 손실 함수로 'binary_crossentropy'를 사용한다.

# %%
model = Sequential()
model.add(LSTM(20, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), #시계열 데이터의 구조
               activation='relu',return_sequences=False))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='rmsprop',metrics=['accuracy'])

#optimizer='rmsprop'
#optimizer='adam'

model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_20 (LSTM)               (None, 20)                2240
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 2,261
# Trainable params: 2,261
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 모델 업데이트 과정 저장을 위한 환경 설정

# %%
# 모델 저장 폴더 생성
model_dir='./model_save'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
    
# 파일 저장 경로
model_path='./model_save/3_'+str(window_size)+'_{epoch:d}_{val_loss:.4f}_{val_accuracy:.4f}.h5'

# %%
model_path
# Out:
# './model_save/3_5_{epoch:d}_{val_loss:.4f}_{val_accuracy:.4f}.h5'

# %%
# 학습 자동 중단 설정
# 20번 연속 성능에 변화 없으면 학습 멈춤
early_stop = EarlyStopping(monitor='val_loss', patience=20)

# %%
# 모델 업데이트 및 저장
checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)

# %%
history = model.fit(X_train, Y_train,                     
                    validation_data=(X_valid, Y_valid), 
                    epochs=200, 
                    batch_size=15, 
                    callbacks=[early_stop, checkpoint])
# Out:
# Train on 331 samples, validate on 83 samples
# Epoch 1/200
# 180/331 [===============>..............] - ETA: 1s - loss: 0.6925 - accuracy: 0.5278
# Epoch 00001: val_loss improved from inf to 0.69348, saving model to ./model_save/3_5_1_0.6935_0.4578.h5
# 331/331 [==============================] - 2s 5ms/sample - loss: 0.6928 - accuracy: 0.5166 - val_loss: 0.6935 - val_accuracy: 0.4578
# Epoch 2/200
# 210/331 [==================>...........] - ETA: 0s - loss: 0.6929 - accuracy: 0.5143
# Epoch 00002: val_loss did not improve from 0.69348
# 331/331 [==============================] - 0s 318us/sample - loss: 0.6922 - accuracy: 0.5166 - val_loss: 0.6941 - val_accuracy: 0.4699
# Epoch 3/200
# 240/331 [====================>.........] - ETA: 0s - loss: 0.6912 - accuracy: 0.5375
# Epoch 00003: val_loss improved from 0.69348 to 0.69313, saving model to ./model_save/3_5_3_0.6931_0.4578.h5
# 331/331 [==============================] - 0s 321us/sample - loss: 0.6921 - accuracy: 0.5257 - val_loss: 0.6931 - val_accuracy: 0.4578
# Epoch 4/200
# 225/331 [===================>..........] - ETA: 0s - loss: 0.6907 - accuracy: 0.5378
# Epoch 00004: val_loss improved from 0.69313 to 0.69208, saving model to ./model_save/3_5_4_0.6921_0.4940.h5
# 331/331 [==============================] - 0s 340us/sample - loss: 0.6919 - accuracy: 0.5257 - val_loss: 0.6921 - val_accuracy: 0.4940
# Epoch 5/200
# 240/331 [====================>.........] - ETA: 0s - loss: 0.6914 - accuracy: 0.5458
# Epoch 00005: val_loss improved from 0.69208 to 0.69169, saving model to ./model_save/3_5_5_0.6917_0.5181.h5
# 331/331 [==============================] - 0s 319us/sample - loss: 0.6916 - accuracy: 0.5347 - val_loss: 0.6917 - val_accuracy: 0.5181
# Epoch 6/200
# 210/331 [==================>...........] - ETA: 0s - loss: 0.6902 - accuracy: 0.5714
# Epoch 00006: val_loss improved from 0.69169 to 0.69113, saving model to ./model_save/3_5_6_0.6911_0.5422.h5
# 331/331 [==============================] - 0s 346us/sample - loss: 0.6916 - accuracy: 0.5438 - val_loss: 0.6911 - val_accuracy: 0.5422
# Epoch 7/200
# 225/331 [===================>..........] - ETA: 0s - loss: 0.6923 - accuracy: 0.5689
# Epoch 00007: val_loss did not improve from 0.69113
# 331/331 [==============================] - 0s 309us/sample - loss: 0.6917 - accuracy: 0.5529 - val_loss: 0.6922 - val_accuracy: 0.4940
# Epoch 8/200
# 240/331 [====================>.........] - ETA: 0s - loss: 0.6904 - accuracy: 0.5417
# Epoch 00008: val_loss improved from 0.69113 to 0.69102, saving model to ./model_save/3_5_8_0.6910_0.5060.h5
# 331/331 [==============================] - 0s 325us/sample - loss: 0.6915 - accuracy: 0.5196 - val_loss: 0.6910 - val_accuracy: 0.5060
# Epoch 9/200
# 240/331 [====================>.........] - ETA: 0s - loss: 0.6910 - accuracy: 0.5625
# Epoch 00009: val_loss improved from 0.69102 to 0.69038, saving model to ./model_save/3_5_9_0.6904_0.5422.h5
# 331/331 [==============================] - 0s 314us/sample - loss: 0.6913 - accuracy: 0.5650 - val_loss: 0.6904 - val_accuracy: 0.5422
# Epoch 10/200
# 225/331 [===================>..........] - ETA: 0s - loss: 0.6895 - accuracy: 0.5822
# Epoch 00010: val_loss improved from 0.69038 to 0.69012, saving model to ./model_save/3_5_10_0.6901_0.5422.h5
# 331/331 [==============================] - 0s 326us/sample - loss: 0.6912 - accuracy: 0.5438 - val_loss: 0.6901 - val_accuracy: 0.5422
# Epoch 11/200
# 225/331 [===================>..........] - ETA: 0s - loss: 0.
200
# 180/331 [===============>..............] - ETA: 0s - loss: 0.6622 - accuracy: 0.6278
# Epoch 00096: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 404us/sample - loss: 0.6762 - accuracy: 0.5891 - val_loss: 0.6902 - val_accuracy: 0.5301
# Epoch 97/200
# 180/331 [===============>..............] - ETA: 0s - loss: 0.6783 - accuracy: 0.5667
# Epoch 00097: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 408us/sample - loss: 0.6756 - accuracy: 0.5529 - val_loss: 0.6831 - val_accuracy: 0.5422
# Epoch 98/200
# 330/331 [============================>.] - ETA: 0s - loss: 0.6743 - accuracy: 0.5788
# Epoch 00098: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 422us/sample - loss: 0.6748 - accuracy: 0.5770 - val_loss: 0.6799 - val_accuracy: 0.5422
# Epoch 99/200
# 180/331 [===============>..............] - ETA: 0s - loss: 0.6721 - accuracy: 0.6222
# Epoch 00099: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 404us/sample - loss: 0.6749 - accuracy: 0.6012 - val_loss: 0.6787 - val_accuracy: 0.5422
# Epoch 100/200
# 180/331 [===============>..............] - ETA: 0s - loss: 0.6735 - accuracy: 0.6167
# Epoch 00100: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 392us/sample - loss: 0.6747 - accuracy: 0.6103 - val_loss: 0.6878 - val_accuracy: 0.5542
# Epoch 101/200
# 195/331 [================>.............] - ETA: 0s - loss: 0.6800 - accuracy: 0.5590
# Epoch 00101: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 376us/sample - loss: 0.6748 - accuracy: 0.5740 - val_loss: 0.6899 - val_accuracy: 0.5542
# Epoch 102/200
# 180/331 [===============>..............] - ETA: 0s - loss: 0.6747 - accuracy: 0.5444
# Epoch 00102: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 384us/sample - loss: 0.6732 - accuracy: 0.5619 - val_loss: 0.6881 - val_accuracy: 0.5663
# Epoch 103/200
# 195/331 [================>.............] - ETA: 0s - loss: 0.6730 - accuracy: 0.6000
# Epoch 00103: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 383us/sample - loss: 0.6726 - accuracy: 0.5801 - val_loss: 0.6815 - val_accuracy: 0.5422
# Epoch 104/200
# 195/331 [================>.............] - ETA: 0s - loss: 0.6510 - accuracy: 0.6462
# Epoch 00104: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 388us/sample - loss: 0.6718 - accuracy: 0.5861 - val_loss: 0.6870 - val_accuracy: 0.5663
# Epoch 105/200
# 180/331 [===============>..............] - ETA: 0s - loss: 0.6633 - accuracy: 0.5722
# Epoch 00105: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 386us/sample - loss: 0.6697 - accuracy: 0.5861 - val_loss: 0.6795 - val_accuracy: 0.5542
# Epoch 106/200
# 195/331 [================>.............] - ETA: 0s - loss: 0.6853 - accuracy: 0.73 - ETA: 0s - loss: 0.6734 - accuracy: 0.6205
# Epoch 00106: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 383us/sample - loss: 0.6724 - accuracy: 0.6012 - val_loss: 0.6793 - val_accuracy: 0.5663
# Epoch 107/200
# 195/331 [================>.............] - ETA: 0s - loss: 0.6754 - accuracy: 0.6051
# Epoch 00107: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 382us/sample - loss: 0.6704 - accuracy: 0.6073 - val_loss: 0.6869 - val_accuracy: 0.5422
# Epoch 108/200
# 180/331 [===============>..............] - ETA: 0s - loss: 0.6702 - accuracy: 0.5667
# Epoch 00108: val_loss did not improve from 0.67857
# 331/331 [==============================] - 0s 390us/sample - loss: 0.6685 - accuracy: 0.5952 - val_loss: 0.6879 - val_accuracy: 0.5542

# %%
history

# %%
print("\nAccuracy : %.4f"%(model.evaluate(train_feature,train_class)[1]))
# Out:
# 414/414 [==============================] - 0s 73us/sample - loss: 0.6706 - accuracy: 0.5749
#
# Accuracy : 0.5749

# %%
print("\nAccuracy : %.4f"%(model.evaluate(test_feature,test_class)[1]))
# Out:
# 175/175 [==============================] - 0s 86us/sample - loss: 0.7358 - accuracy: 0.4857
#
# Accuracy : 0.4857

# %% [markdown]
# 테스트 데이터셋에 대한 정확도가 50%도 안됨. 탈락.
